# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basic-Notes-Class9/blob/main/AI_Reboot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
True+1
# Out:
# 2

# %%
45+bool(-11)
# Out:
# 46

# %%
2+False+bool(0)
# Out:
# 2

# %%
12-10+bool(10)
# Out:
# 3

# %%
True+"hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3268/412023811.py in <cell line: 0>()
# ----> 1 True+"hello"
#
# TypeError: unsupported operand type(s) for +: 'bool' and 'str'
