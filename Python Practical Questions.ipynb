# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-9/blob/main/Python%20Practical%20Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.To print personal information like Name,Falthers name,Class,School Name**

# %%
Name="Jyothi"
FName="Robert"
Sclass=9
Sch_Name="GMS"
print("***PERSONAL INFROMATION***")
print("Student Name: ",Name)
print("Fathers Name: ",FName)
print("Class: ",Sclass)
print("School Name: ",Sch_Name)
# Out:
# ***PERSONAL INFROMATION***
# Student Name:  Jyothi
# Fathers Name:  Robert
# Class:  9
# School Name:  GMS

# %% [markdown]
# **2.To print the following patterns using multiple print commands:\
# a)
#
# ![image.png](data:image/png;base64,...)
#
#
#
# b)
#
# ![image.png](data:image/png;base64,...)

# %%
print("*")
print("**")
print("***")
print("****")
# Out:
# *
# **
# ***
# ****

# %%
print("****")
print(" ***")
print("  **")
print("   *")
# Out:
# ****
#  ***
#   **
#    *

# %% [markdown]
# **3.To find square of number 7**

# %%
N=7
print("Square of",N, " is : ",N**2)
# Out:
# Square of 7  is :  49
