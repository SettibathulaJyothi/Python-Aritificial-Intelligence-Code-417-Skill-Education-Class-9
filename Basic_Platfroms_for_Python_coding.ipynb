# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Aritificial-Intelligence-Code-417-Skill-Education-Class-9/blob/main/Basic_Platfroms_for_Python_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/
#
# https://www.programiz.com/python-programming/online-compiler/
#
#
# https://www.python.org/
#
# https://www.anaconda.com/
#
# https://codecombat.com/
